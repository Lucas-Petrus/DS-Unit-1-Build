# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-Petrus/DS-Unit-1-Build/blob/master/NBA_Referee_Stats_Unit_Build_1(Day1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.nbastuffer.com/2019-2020-nba-referee-stats/

# %% [markdown]
# **The data set below is a compliation of all the different referees in NBA. Over the couple years, a lot of information has been coming out about how refs might be manipulating scores for either NBA viewership purposes or potentially rigging games for gambling purposes (lets hope not!)**
#
# In order to drive more views, it would make sense to me that the NBA would be telling officials to call less fouls on the Home Team giving them a better chance to win, driving more fans into the arena to watch a winning team, and letting the home fans enjoy a win that they bought tickets to hopefully see.
#
# **My question for this data is: Do referees go easier on calls on home teams?**

# %%
import pandas as pd

# %%
df = pd.read_excel('NBA Referee Stats.xlsx')
print(df.shape)
df.head()
# Out:
# (123, 11)
#    Rank              Referee  ...  Foul % Against Home Teams  Foul Differential
# 0     1            Karl Lane  ...                     50.571               -0.4
# 1     2           Tyler Ford  ...                     48.514                1.2
# 2     3        Dedric Taylor  ...                     49.362                0.6
# 3     4  Gediminas Petraitis  ...                     47.880                1.7
# 4     5       Mitchell Ervin  ...                     49.138                0.8
#
# [5 rows x 11 columns]

# %%
df['Home Team Win%'] = df['Home Team Win%']*100

df.head()
# Out:
#    Rank              Referee  ...  Foul % Against Home Teams  Foul Differential
# 0     1            Karl Lane  ...                     50.571               -0.4
# 1     2           Tyler Ford  ...                     48.514                1.2
# 2     3        Dedric Taylor  ...                     49.362                0.6
# 3     4  Gediminas Petraitis  ...                     47.880                1.7
# 4     5       Mitchell Ervin  ...                     49.138                0.8
#
# [5 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Rank                         0
# Referee                      0
# Experience (Years)           0
# Games Officiated             0
# Home Team Win%               0
# Home Team Points Diff        0
# Total Points Per Game        0
# Called Fouls Per Game        0
# Foul % Against Road Teams    0
# Foul % Against Home Teams    0
# Foul Differential            0
# dtype: int64

# %%
df.describe()
# Out:
#              Rank  ...  Foul Differential
# count  123.000000  ...         123.000000
# mean    62.000000  ...           0.463415
# std     35.651087  ...           2.163606
# min      1.000000  ...          -9.000000
# 25%     31.500000  ...          -0.400000
# 50%     62.000000  ...           0.400000
# 75%     92.500000  ...           1.050000
# max    123.000000  ...          12.000000
#
# [8 rows x 10 columns]

# %%
pd.crosstab(df['Foul % Against Road Teams'],df['Foul % Against Home Teams'])
# Out:
# Foul % Against Home Teams  35.000  40.506  42.308  ...  53.254  55.883  60.976
# Foul % Against Road Teams                          ...
# 39.024                          0       0       0  ...       0       0       1
# 44.118                          0       0       0  ...       0       1       0
# 46.746                          0       0       0  ...       1       0       0
# 46.832                          0       0       0  ...       0       0       0
# 46.939                          0       0       0  ...       0       0       0
# ...                           ...     ...     ...  ...     ...     ...     ...
# 56.250                          0       0       0  ...       0       0       0
# 57.647                          0       0       0  ...       0       0       0
# 57.692                          0       0       1  ...       0       0       0
# 59.494                          0       1       0  ...       0       0       0
# ...

# %%
df.hist(['Foul % Against Home Teams'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0adeb2fc88>]],
#       dtype=object)

# %%
df.hist(['Foul % Against Road Teams'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0adc807748>]],
#       dtype=object)

# %%
df.plot.scatter('Foul % Against Road Teams', 'Foul % Against Home Teams');

# %%
df.plot.scatter('Home Team Win%', 'Foul Differential');

# %%
# !pip install plotly
import plotly.express as px

# %%
df.head()
# Out:
#    Rank              Referee  ...  Foul % Against Home Teams  Foul Differential
# 0     1            Karl Lane  ...                     50.571               -0.4
# 1     2           Tyler Ford  ...                     48.514                1.2
# 2     3        Dedric Taylor  ...                     49.362                0.6
# 3     4  Gediminas Petraitis  ...                     47.880                1.7
# 4     5       Mitchell Ervin  ...                     49.138                0.8
#
# [5 rows x 11 columns]

# %%
df.sort_values(by='Games Officiated', inplace=True, ascending=False)
df.head(20)
# Out:
#     Rank              Referee  ...  Foul % Against Home Teams  Foul Differential
# 3      4  Gediminas Petraitis  ...                     47.880                1.7
# 1      2           Tyler Ford  ...                     48.514                1.2
# 2      3        Dedric Taylor  ...                     49.362                0.6
# 4      5       Mitchell Ervin  ...                     49.138                0.8
# 0      1            Karl Lane  ...                     50.571               -0.4
# 7      8             J.T. Orr  ...                     51.404               -1.1
# 8      9        Tony Brothers  ...                     47.500                2.0
# 6      7      Scott Twardoski  ...                     50.102               -0.1
# 10    11           Ben Taylor  ...                     48.858                1.0
# 11    12         Nick Buchert  ...                     49.251                0.6
# 9     10          Sean Corbin  ...                     49.646                0.3
# ...

# %%
import plotly.express as px
fig = px.scatter(df, x="Called Fouls Per Game", y="Foul % Against Road Teams")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cf3d9325-712d-4d3a-a166-fdefd278d387" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf3d9325-712d-4d3a-a166-fdefd278d387")) {
#                     Plotly.newPlot(
#                         'cf3d9325-712d-4d3a-a166-fdefd278d387',
# ...

# %%
import plotly.express as px
fig = px.scatter(df, x="Experience (Years)", y="Foul % Against Home Teams")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e7298381-a3e0-4352-adc2-7cfdb34c706e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7298381-a3e0-4352-adc2-7cfdb34c706e")) {
#                     Plotly.newPlot(
#                         'e7298381-a3e0-4352-adc2-7cfdb34c706e',
# ...

# %%
import plotly.express as px
fig = px.bar(df, x="Experience (Years)", y="Home Team Win%")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f28d5f87-5617-40c3-a1d3-46db1c691a4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f28d5f87-5617-40c3-a1d3-46db1c691a4b")) {
#                     Plotly.newPlot(
#                         'f28d5f87-5617-40c3-a1d3-46db1c691a4b',
# ...
